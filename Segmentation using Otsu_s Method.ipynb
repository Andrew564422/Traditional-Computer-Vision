# %% [markdown]
# ## Otsu's Method
# ### this method can get the value of thresolding itself using rule, this value maximize variance between classes

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import cv2

from google.colab.patches import cv2_imshow

# %%
img= cv2.imread("/content/drive/MyDrive/Computer_vision/Traditional Computer Vision/Image Enhancement/lena.jpg", 0)

cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=320x320>

# %%
ret, thr= cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

cv2_imshow(thr)
# Out:
# <PIL.Image.Image image mode=L size=320x320>

# %%
blur= cv2.GaussianBlur(img, (5, 5), 0)

ret, ther= cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

cv2_imshow(ther)
# Out:
# <PIL.Image.Image image mode=L size=320x320>
